# %%
message = 'Bienvenido al Curso Master en Azure Databricks & Spark para Data Engineers'

# %%
print(message)
# Out:
# Bienvenido al Curso Master en Azure Databricks & Spark para Data Engineers

# %%
message = "Hello World"
display(message)
# Out:
# 'Hello World'
