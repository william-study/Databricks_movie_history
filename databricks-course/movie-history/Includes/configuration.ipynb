# %%
bronze_folder_path = "abfss://bronze@moviehistory310785.dfs.core.windows.net"
silver_folder_path = "abfss://silver@moviehistory310785.dfs.core.windows.net"
gold_folder_path = "abfss://gold@moviehistory310785.dfs.core.windows.net"
