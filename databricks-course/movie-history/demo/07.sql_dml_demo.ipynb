-- %%
SHOW DATABASES;

-- %%
SELECT current_database();

-- %%
USE movie_silver;

-- %%
SHOW TABLES;

-- %%
SELECT * FROM movies;

-- %%
DESCRIBE movies;

-- %%
SELECT * FROM movies
LIMIT 100;

-- %%
SELECT *
FROM movies
WHERE year_Release_Date = 2015 AND vote_Average >= 7.5
ORDER BY vote_Average DESC;
