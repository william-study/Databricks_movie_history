-- %%
CREATE SCHEMA IF NOT EXISTS movie_silver
MANAGED LOCATION "abfss://silver@moviehistory310785.dfs.core.windows.net/";

-- %%
DESCRIBE DATABASE movie_silver;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database_description_item</th><th>database_description_value</th></tr></thead><tbody><tr><td>Catalog Name</td><td>databricks_course_ws</td></tr><tr><td>Namespace Name</td><td>movie_silver</td></tr><tr><td>Comment</td><td></td></tr><tr><td>Location</td><td>abfss://silver@moviehistory310785.dfs.core.windows.net/__unitystorage/schemas/8213aa93-c5cd-403d-ac67-82449783254d</td></tr><tr><td>Owner</td><td>mi.peque.valentina.2026@gmail.com</td></tr><tr><td>RootLocation</td><td>abfss://silver@moviehistory310785.dfs.core.windows.net/</td></tr></tbody></table></div>

-- %%
SHOW TABLES IN movie_silver;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td></td><td>_sqldf</td><td>true</td></tr></tbody></table></div>
