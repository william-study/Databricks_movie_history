-- %% [markdown]
-- ### Configurar Acceso Azure Data Lake Storage Gen2
-- 1. Crear el objeto "External Location" llamado "external_location_bronze_mov_his"
-- 2. Crear el objeto "External Location" llamado "external_location_silver_mov_his"
-- 3. Crear el objeto "External Location" llamado "external_location_gold_mov_his"
-- 4. Validar el acceso a los objetos "External Locations" creados

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS external_location_bronze_mov_his
    URL 'abfss://bronze@moviehistory310785.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL storage_credential_mov_his)
    COMMENT 'External Location for the Bronze Lakehouse.'

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS external_location_silver_mov_his
    URL 'abfss://silver@moviehistory310785.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL storage_credential_mov_his)
    COMMENT 'External Location for the Silver Lakehouse.'

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS external_location_gold_mov_his
    URL 'abfss://gold@moviehistory310785.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL storage_credential_mov_his)
    COMMENT 'External Location for the Gold Lakehouse.'

-- %%
%python
dbutils.fs.ls("abfss://bronze@moviehistory310785.dfs.core.windows.net/")
-- Out:
-- []

-- %%
%python
dbutils.fs.ls("abfss://silver@moviehistory310785.dfs.core.windows.net/")
-- Out:
-- []

-- %%
%python
dbutils.fs.ls("abfss://gold@moviehistory310785.dfs.core.windows.net/")
-- Out:
-- []

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS external_location_demo_mov_his
    URL 'abfss://demo@moviehistory310785.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL storage_credential_mov_his)
    COMMENT 'External Location for the Demo Lakehouse.'

-- %%
%python
dbutils.fs.ls("abfss://demo@moviehistory310785.dfs.core.windows.net/")
-- Out:
-- [FileInfo(path='abfss://demo@moviehistory310785.dfs.core.windows.net/movie.csv', name='movie.csv', size=2107979, modificationTime=1787935152000)]
