-- %% [markdown]
-- ####Eliminar y volver a crear todas las Base de Datos

-- %%
DROP DATABASE IF EXISTS movie_silver CASCADE;

-- %%
CREATE SCHEMA IF NOT EXISTS movie_silver
MANAGED LOCATION "abfss://silver@moviehistory310785.dfs.core.windows.net/";

-- %%
DROP DATABASE IF EXISTS movie_gold CASCADE;

-- %%
CREATE SCHEMA IF NOT EXISTS movie_gold
MANAGED LOCATION "abfss://gold@moviehistory310785.dfs.core.windows.net/";
